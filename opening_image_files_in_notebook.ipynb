# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('img/MainAfter.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_img)

# %%
img_gray = cv2.imread('img/MainAfter.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (720, 1280)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray, cmap="gray")

# %%
resized_img = cv2.resize(rgb_img, (1000, 400))

# %%
plt.imshow(resized_img)

# %%
w_ratio = 0.5
h_ratio = 0.5
ratio_resized_img = cv2.resize(rgb_img, (0, 0), rgb_img, w_ratio, h_ratio)

# %%
plt.imshow(ratio_resized_img)

# %%
flipped_img = cv2.flip(rgb_img, -1)

# %%
plt.imshow(flipped_img)

# %%
cv2.imwrite('img/MainAfter_flipped.jpg', flipped_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
ax.imshow(rgb_img)
